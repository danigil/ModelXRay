# %%
import numpy as np
import requests

url = 'http://127.0.0.1:8001'

# %%
x = requests.get(f'{url}/list_models')
x.text
# Out:
# '{"gf_1lsb.keras":{"image_rep_config":{"image_rep_proc_config":{"image_rep_type":"grayscale_fourpart"}},"image_preprocess_config":{"image_height":100,"image_width":100,"image_reshape_algo":"bicubic","image_preprocess_config":{"image_preprocess_backend":"pillow"}}}}'

# %%
img = np.random.rand(100, 100)
inputs = [img.tolist()]

request = {
    'model_names': ['siamese_famous_le_10m_grayscale_fourpart_100_binary_file_ub_1_0.keras'],
    'inputs': inputs
}

x = requests.post(f'{url}/inference', json=request)
x.text
# Out:
# '{"siamese_famous_le_10m_grayscale_fourpart_100_binary_file_ub_1_0.keras":[0]}'
